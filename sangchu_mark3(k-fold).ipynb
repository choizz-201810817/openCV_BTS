# %%
# !pip install --upgrade pip

# %%
# !pip install tensorflow

# %%
# !pip install keras

# %% [markdown]
# ### GPU 사용 설정

# %%
# !pip install tensorflow-gpu

# %%
# from tensorflow.python.client import device_lib
# print(device_lib.list_local_devices())

# %%
# import tensorflow as tf

# tf.test.is_gpu_available()

# %%
# import os

# # os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
# os.environ["CUDA_VISIBLE_DEVICES"]= "0"

# %% [markdown]
# ### 데이터 불러오기

# %%
import pandas as pd
import numpy as np

## 최대 크기 case_11 // 최소 크기 case_21
case_11 = pd.read_csv('./CASE_11.csv')
case_21 = pd.read_csv('./CASE_21.csv')

# case_11['case'] = 11
# case_21['case'] = 21

# compare_df = pd.concat([case_11, case_21]).reset_index(drop=True)
# compare_df

# %%
case_21.iloc[:,[8,10,12]]
# Out:
#         시간당백색광량    시간당적색광량   시간당청색광량
# 0        0.0000     0.0000     0.000
# 1        0.0000     0.0000     0.000
# 2        0.0000     0.0000     0.000
# 3        0.0000     0.0000     0.000
# 4        0.0000     0.0000     0.000
# ..          ...        ...       ...
# 667  18255.1900  9763.3200  9242.350
# 668  18255.1900  9763.3200  9242.350
# 669    754.9604   403.7712   382.226
# 670      0.0000     0.0000     0.000
# 671      0.0000     0.0000     0.000
#
# [672 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15,7))
plt.plot(case_11.index, case_11['내부온도관측치'], color='blueviolet')
plt.plot(case_21.index, case_21['내부온도관측치'], color='forestgreen')

plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(case_11.index, case_11['내부습도관측치'], color='blueviolet')
plt.plot(case_21.index, case_21['내부습도관측치'], color='forestgreen')

plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(case_11.index, case_11['co2관측치'], color='blueviolet')
plt.plot(case_21.index, case_21['co2관측치'], color='forestgreen')

plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(case_11.index, case_11['ec관측치'], color='blueviolet')
plt.plot(case_21.index, case_21['ec관측치'], color='forestgreen')

plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(case_11.index, case_11['시간당분무량'], color='blueviolet')
plt.plot(case_21.index, case_21['시간당분무량'], color='forestgreen')

plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(case_11.index, case_11['시간당백색광량'], color='blueviolet')
plt.plot(case_21.index, case_21['시간당백색광량'], color='forestgreen')

plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(case_11.index, case_11['시간당적색광량'], color='blueviolet')
plt.plot(case_21.index, case_21['시간당적색광량'], color='forestgreen')

plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(case_11.index, case_11['시간당청색광량'], color='blueviolet')
plt.plot(case_21.index, case_21['시간당청색광량'], color='forestgreen')

plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(case_11.index, case_11['시간당총광량'], color='blueviolet')
plt.plot(case_21.index, case_21['시간당총광량'], color='forestgreen')

plt.show()

# %%
import pandas as pd
import numpy as np
import os

files = os.listdir('./')

train_df_list = []

for file in files:
    if 'CASE' in file:
        df = pd.read_csv(file)
        train_df_list.append(df)

# %%
df = pd.concat(train_df_list).reset_index(drop=True)

# %%
pd.set_option('display.max_rows', 10)
df['obs_time'] = df['obs_time'].apply(lambda x: '02:00:00.' if x=='01:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '03:00:00.' if x=='02:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '04:00:00.' if x=='03:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '05:00:00.' if x=='04:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '06:00:00.' if x=='05:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '07:00:00.' if x=='06:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '08:00:00.' if x=='07:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '09:00:00.' if x=='08:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '10:00:00.' if x=='09:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '11:00:00.' if x=='10:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '12:00:00.' if x=='11:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '13:00:00.' if x=='12:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '14:00:00.' if x=='13:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '15:00:00.' if x=='14:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '16:00:00.' if x=='15:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '17:00:00.' if x=='16:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '18:00:00.' if x=='17:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '19:00:00.' if x=='18:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '20:00:00.' if x=='19:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '21:00:00.' if x=='20:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '22:00:00.' if x=='21:59:59.' else x)
df['obs_time'] = df['obs_time'].apply(lambda x: '23:00:00.' if x=='22:59:59.' else x)

# %%
pd.set_option('display.max_rows', 10)
df
# Out:
#        DAT obs_time    내부온도관측치    내부습도관측치      co2관측치     ec관측치  시간당분무량  \
# 0        0    00:00  25.300000  81.835000  536.016667  1.407439     0.0
# 1        0    01:00  25.680357  81.264286  528.696429  1.409003   126.0
# 2        0    02:00  25.273333  81.471666  532.833333  1.406913     0.0
# 3        0    03:00  25.355000  81.398334  545.566667  1.406689   126.0
# 4        0    04:00  25.391667  81.483333  558.583333  1.411070     0.0
# ...    ...      ...        ...        ...         ...       ...     ...
# 18811   27    19:00  26.030000  58.736667  448.500000  1.195415     0.0
# 18812   27    20:00  27.341666  58.373334  449.183333  1.190780   126.0
# 18813   27    21:00  27.785000  58.711667  441.933333  1.185593     0.0
# 18814   27    22:00  28.480000  58.121667  437.600000  1.179664     0.0
# 18815   27    23:00  28.595000  58.598333  430.266667  1.175694     0.0
#
#        일간누적분무량  시간당백색광량    일간누적백색광량  시간당적색광량    일간누적적색광량  시간당청색광량    일간누적청색광량  \
# ...

# %%
def prepro(df):
    df.obs_time = df.obs_time.apply(lambda x: x[:2]).astype('int')
    df = df.abs()
    
    return df

# %%
df1 = prepro(df)

# 0시~5시 지우기
# df1 = df1[df1.obs_time > 5].reset_index(drop=True)

# %%
# 관측치
df1['내부온도관측치'] = df1['내부온도관측치'].apply(lambda x: 4 if x<4 else x)
df1['내부온도관측치'] = df1['내부온도관측치'].apply(lambda x: 40 if x>40 else x)
df1['내부습도관측치'] = df1['내부습도관측치'].apply(lambda x: 100 if x>100 else x)
df1['co2관측치'] = df1['co2관측치'].apply(lambda x: 1200 if x>1200 else x)
df1['ec관측치'] = df1['ec관측치'].apply(lambda x: 8 if x>8 else x)

# 분무량
df1['시간당분무량'] = df1['시간당분무량'].apply(lambda x: 3000 if x>3000 else x)
df1['일간누적분무량'] = df1['일간누적분무량'].apply(lambda x: 72000 if x>72000 else x)

# 광량
df1['시간당백색광량'] = df1['시간당백색광량'].apply(lambda x: 120000 if x>120000 else x)
df1['시간당적색광량'] = df1['시간당적색광량'].apply(lambda x: 120000 if x>120000 else x)
df1['시간당청색광량'] = df1['시간당청색광량'].apply(lambda x: 120000 if x>120000 else x)
df1['시간당총광량'] = df1['시간당총광량'].apply(lambda x: 120000 if x>120000 else x)
df1['일간누적백색광량'] = df1['일간누적백색광량'].apply(lambda x: 2880000 if x>2880000 else x)
df1['일간누적적색광량'] = df1['일간누적적색광량'].apply(lambda x: 2880000 if x>2880000 else x)
df1['일간누적청색광량'] = df1['일간누적청색광량'].apply(lambda x: 2880000 if x>2880000 else x)
df1['일간누적총광량'] = df1['일간누적총광량'].apply(lambda x: 2880000 if x>2880000 else x)

# %%
def find_outlier(df):
    # 관측치
    print(((4<=df['내부온도관측치'])&(df['내부온도관측치']<=40)).value_counts())
    print('\n',((0<=df['내부습도관측치'])&(df['내부습도관측치']<=100)).value_counts())
    print('\n',((0<=df['co2관측치'])&(df['co2관측치']<=1200)).value_counts())
    print('\n',((0<=df['ec관측치'])&(df['ec관측치']<=8)).value_counts())


    # 분무량
    print('\n',((0<=df['시간당분무량'])&(df['시간당분무량']<=3000)).value_counts())
    print('\n',((0<=df['일간누적분무량'])&(df['일간누적분무량']<=72000)).value_counts())

    # 광량
    print('\n',((0<=df['시간당백색광량'])&(df['시간당백색광량']<=120000)).value_counts())
    print('\n',((0<=df['시간당적색광량'])&(df['시간당적색광량']<=120000)).value_counts())
    print('\n',((0<=df['시간당청색광량'])&(df['시간당청색광량']<=120000)).value_counts())
    print('\n',((0<=df['시간당총광량'])&(df['시간당총광량']<=120000)).value_counts())
    print('\n',((0<=df['일간누적백색광량'])&(df['일간누적백색광량']<=2880000)).value_counts())
    print('\n',((0<=df['일간누적적색광량'])&(df['일간누적적색광량']<=2880000)).value_counts())
    print('\n',((0<=df['일간누적청색광량'])&(df['일간누적청색광량']<=2880000)).value_counts())
    print('\n',((0<=df['일간누적총광량'])&(df['일간누적총광량']<=2880000)).value_counts())

# %%
find_outlier(df1)
# Out:
# True    18816
# Name: 내부온도관측치, dtype: int64
#
#  True    18816
# Name: 내부습도관측치, dtype: int64
#
#  True    18816
# Name: co2관측치, dtype: int64
#
#  True    18816
# Name: ec관측치, dtype: int64
#
#  True    18816
# Name: 시간당분무량, dtype: int64
#
#  True    18816
# Name: 일간누적분무량, dtype: int64
#
#  True    18816
# Name: 시간당백색광량, dtype: int64
#
#  True    18816
# Name: 시간당적색광량, dtype: int64
#
#  True    18816
# Name: 시간당청색광량, dtype: int64
#
#  True    18816
# Name: 시간당총광량, dtype: int64
#
#  True    18816
# Name: 일간누적백색광량, dtype: int64
#
#  True    18816
# Name: 일간누적적색광량, dtype: int64
#
#  True    18816
# Name: 일간누적청색광량, dtype: int64
#
#  True    18816
# Name: 일간누적총광량, dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler

mm_sc = MinMaxScaler()
mm_array = mm_sc.fit_transform(df1)

# %%
mm_df = pd.DataFrame(mm_array, columns=df1.columns.tolist())

## 일간누적
# mm_df1 = mm_df.iloc[:,[0,2,3,4,5,7,9,11,13,15]]

## 시간당
mm_df1 = mm_df.iloc[:,[0,2,3,4,5,6,8,10,12,14]]
# mm_df1 = pd.concat([df1.DAT, mm_df.iloc[:,[2,3,4,5,6,8,10,12,14]]], axis=1)

## 전부 사용
# mm_df1 = mm_df.drop(['obs_time'], axis=1)

mm_df1
# Out:
#        DAT   내부온도관측치   내부습도관측치    co2관측치     ec관측치  시간당분무량   시간당백색광량  시간당적색광량  \
# 0      0.0  0.591667  0.876647  0.417354  0.257663   0.000  0.000000      0.0
# 1      0.0  0.602232  0.870533  0.410931  0.257949   0.042  0.000000      0.0
# 2      0.0  0.590926  0.872755  0.414561  0.257567   0.000  0.000000      0.0
# 3      0.0  0.593194  0.871969  0.425734  0.257526   0.042  0.000000      0.0
# 4      0.0  0.594213  0.872880  0.437156  0.258328   0.000  0.000000      0.0
# ...    ...       ...       ...       ...       ...     ...       ...      ...
# 18811  1.0  0.611944  0.629209  0.340558  0.218847   0.000  0.000103      0.0
# 18812  1.0  0.648380  0.625317  0.341158  0.217999   0.042  0.000000      0.0
# 18813  1.0  0.660694  0.628941  0.334796  0.217049   0.000  0.000000      0.0
# 18814  1.0  0.680000  0.622621  0.330993  0.215964   0.000  0.000000      0.0
# 18815  1.0  0.683194  0.627727  0.324558  0.215237   0.000  0.000000      0.0
#
#        시간당청색광량    시간당총광량
# ...

# %%
def slice_18(df):
    array_list = []
    
    for i in range(int(len(df)/18)):
        one_day_array = df.iloc[i*18:(i+1)*18,:].to_numpy() # 18시간 간격으로 자름 (0~5시 자른 경우)
        array_list.append(one_day_array)
    
    return array_list

def slice_24(df):
    array_list = []
    
    for i in range(int(len(df)/24)):
        one_day_array = df.iloc[i*24:(i+1)*24,:].to_numpy() # 24시간 간격으로 자름
        array_list.append(one_day_array)
    
    return array_list

sliced_array_list = slice_24(mm_df1)

input_data = np.array(sliced_array_list)
input_data = input_data.reshape(784,24,10,1)
input_data.shape

# reshape 끝에 1을 찍어주는 이유는 LSTM이 3차원의 input값을 받는데 이 형태를 맞춰주기 위함임. (여기서는 필요 x)
# input_data = np.array(sliced_array_list).reshape(784,24,14,1)
# Out:
# (784, 24, 10, 1)

# %%
path = 'C:/Users/ASIA-15/Desktop/Digital_Dev/sangchu/open/train_target/'
# path = 'C:/Users/fckd0/OneDrive/바탕 화면/sangchu/open/train_target/'
files = os.listdir(path)

target_df_list = []

for file in files:
    if 'csv' in file:
        df2 = pd.read_csv(path+file)
        target_df_list.append(df2)
        
        
# 기존 target data에서 일별 성장량을 구해 target값으로 사용하니
# loss값이 현저하게 줄어들었음. (당연...)
for tar_df in target_df_list:
    tar_df['성장량'] = tar_df.predicted_weight_g.diff()
    tar_df['성장량'] = tar_df['성장량'].fillna(0)
    
target_df = pd.concat(target_df_list)['predicted_weight_g'].reset_index(drop=True)
print(target_df)

targets = target_df.values
targets.shape
# Out:
# 0       0.167719
# 1       0.181787
# 2       0.265921
# 3       0.423650
# 4       0.475272
#          ...
# 779    64.875499
# 780    74.002614
# 781    76.342275
# 782    82.621245
# 783    86.591508
# Name: predicted_weight_g, Length: 784, dtype: float64
# (784,)

# %%
# test_df = target_df.apply(lambda x: x for i in range(24))
# targets_copy = test_df.values.reshape(-1,1)

# %%
# time_df = mm_df1
# time_df

# %%
# time_input = np.array(time_df).reshape(18816,10,1)

# print(targets_copy.shape)
# print(time_input.shape)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, LSTM, Conv1D, AveragePooling1D, MaxPooling1D, Dropout, LeakyReLU
from tensorflow.keras.layers import Conv2D, AveragePooling2D, MaxPooling2D, ConvLSTM2D, Input, Reshape
from tensorflow.keras import Model, Sequential, optimizers, regularizers

from keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.model_selection import KFold


# ## train, validation split
# # 672> 24째 CASE까지
# X_train = input_data[:672]
# X_val = input_data[672:]
# y_train = targets[:672]
# y_val = targets[672:]

                
# print(X_train.shape)
# print(y_train.shape)


# train_dataset = [X_train, y_train]
# val_dataset = [X_val, y_val]

# %% [markdown]
# #### 참고
# Total params = recurrent_weights + input_weights + biases
#
# = (num_units*num_units)+(num_features*num_units) + (1*num_units)
#
# = (num_features + num_units)* num_units + num_units

# %%
from keras import backend as K

def rmse(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
hidden_units = 360 # (24*10)의 1.5배로 설정
BATCH_SIZE = 32
EPOCHS = 400
NORM = regularizers.l2(0.01)


kfold = KFold(n_splits=7, shuffle=False)


X_val_list = []
y_val_list = []

for i, (train_idx, val_idx) in enumerate(kfold.split(input_data, targets)):
    print('\n', '-'*10, i, '-'*10, '\n')
    
    X_train, X_val = input_data[train_idx], input_data[val_idx]
    y_train, y_val = targets[train_idx], targets[val_idx]

    # 그래프 그리기 위한 리스트
    X_val_list.append(input_data[val_idx])
    y_val_list.append(targets[val_idx])

    opti = optimizers.Adam(learning_rate=0.01)
    
    leaky_relu = LeakyReLU(0.3)

    early_stopping = EarlyStopping(monitor='val_loss', patience=300, mode='min')

    save_path = './model_save/{epoch:03d}-{val_loss:.4f}.hdf5'
    checkpoint = ModelCheckpoint(filepath=save_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')


    model = Sequential()
    model.add(Conv2D(hidden_units,
                     kernel_size=3,
                     input_shape=(X_train.shape[1:]),
                     kernel_regularizer=NORM,
                     activation=leaky_relu))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Reshape((11, 4*360)))
    model.add(Dropout(0.3))
    model.add(LSTM(hidden_units,
                   activation='tanh', # elu 사용시 기울기 폭주함
                   kernel_regularizer=NORM,
                   return_sequences=False))
    model.add(Dropout(0.3))
    model.add(Dense(1))
    

    
    model.summary()
    model.compile(optimizer=opti, loss=rmse)
    model.fit(X_train, 
              y_train, 
              validation_data=[X_val, y_val], 
              batch_size=BATCH_SIZE, 
              epochs=EPOCHS, 
              verbose=1,
              callbacks=[early_stopping, checkpoint])
# Out:
#  ---------- 0 ----------
#
# Model: "sequential_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_29 (Conv2D)          (None, 22, 8, 360)        3600
#
#  max_pooling2d_13 (MaxPoolin  (None, 11, 4, 360)       0
#  g2D)
#
#  reshape_10 (Reshape)        (None, 11, 1440)          0
#
#  dropout_37 (Dropout)        (None, 11, 1440)          0
#
#  lstm_12 (LSTM)              (None, 360)               2593440
#
#  dropout_38 (Dropout)        (None, 360)               0
#
#  dense_24 (Dense)            (None, 1)                 361
#
# ...
# Total params: 2,597,401
# Trainable params: 2,597,401
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/400
# 21/21 [==============================] - ETA: 0s - loss: 48.4904
# Epoch 1: val_loss improved from inf to 33.74862, saving model to ./model_save\001-33.7486.hdf5
# ...

# %%
# X_val_list = []
# y_val_list = []

# for train_idx, val_idx in kfold.split(input_data, targets):
#     X_val_list.append(input_data[val_idx])
#     y_val_list.append(targets[val_idx])

# %%
from keras.models import load_model
import matplotlib.pyplot as plt
import seaborn as sns

hdf5_path = 'C:/Users/ASIA-15/Desktop/Digital_Dev/sangchu/open/train_input/19-28/새 폴더/model_save/'

files = os.listdir(hdf5_path)

models_list = []

for file in files:
    if 'hdf5' in file:
        models_list.append(hdf5_path+file)


for i, model in enumerate(models_list):
    print('-'*5, '<', model, '>', '-'*5)
    loaded_model = load_model(model, custom_objects={'rmse': rmse})
    
    pred = loaded_model.predict(X_val_list[i])

    yval_df = pd.DataFrame(y_val_list[i])
    pred_df = pd.DataFrame(pred)

    val_pred_df = pd.DataFrame(pd.concat([yval_df, pred_df], axis=1).values, columns=['yval', 'pred'])
    
    plt.figure(figsize=(16,9))
    plt.rcParams['font.family'] = 'HYGothic-Extra'
    title_font = {'fontsize': 16,
                  'fontweight': 'bold'}
    plt.title(model, fontdict=title_font, pad=20)
    sns.lineplot(data=val_pred_df)
# Out:
# ----- < C:/Users/ASIA-15/Desktop/Digital_Dev/sangchu/open/train_input/19-28/새 폴더/model_save/250-15.5004.hdf5 > -----
# 4/4 [==============================] - 0s 29ms/step

# %% [markdown]
# ## TEST

# %%
val_pred_df.to_csv('./dd.csv', encoding='cp949')

# %%
# test_path = 'C:/Users/fckd0/OneDrive/바탕 화면/sangchu/open/test_input/'
test_path = 'C:/Users/ASIA-15/Desktop/Digital_Dev/sangchu/open/test_input/'

files = os.listdir(test_path)

test_df_list = []

for file in files:
    if 'csv' in file:
        df = pd.read_csv(test_path+file)
        test_df_list.append(df)

# %%
test_df = pd.concat(test_df_list).reset_index(drop=True)
# test_df = test_df.drop(['obs_time'], axis=1)

test_df1 = prepro(test_df)

# # 0시~5시 지우기
# test_df1 = test_df1[test_df1.obs_time > 5].reset_index(drop=True)

cols = test_df1.columns.tolist()

# %%
mm_sc = MinMaxScaler()
mm_test = mm_sc.fit_transform(test_df1)
mm_test_df = pd.DataFrame(mm_test, columns=cols)

## 일간누적
# test_df2 = mm_test_df.iloc[:,[0,2,3,4,5,7,9,11,13,15]]

## 시간당
# test_df2 = pd.concat([test_df1.DAT, mm_test_df.iloc[:,[2,3,4,5,6,8,10,12,14]]], axis=1)
test_df2 = mm_test_df.iloc[:,[0,2,3,4,5,6,8,10,12,14]]

## 모두 사용
# test_df2 = mm_test_df.drop(['obs_time'], axis=1)

test_df2
# Out:
#       DAT   내부온도관측치   내부습도관측치    co2관측치     ec관측치    시간당분무량   시간당백색광량  \
# 0     0.0  0.261725  0.578485  0.197276  0.730669  0.000000  0.000000
# 1     0.0  0.273344  0.575470  0.198170  0.731802  0.371075  0.000000
# 2     0.0  0.244656  0.572234  0.198677  0.734435  0.000000  0.000000
# 3     0.0  0.243811  0.577090  0.204206  0.734663  0.371075  0.000000
# 4     0.0  0.266185  0.579299  0.192857  0.735246  0.000000  0.000000
# ...   ...       ...       ...       ...       ...       ...       ...
# 3355  1.0  0.179533  0.562669  0.154537  0.650580  0.000000  0.000333
# 3356  1.0  0.186837  0.547551  0.150698  0.651106  0.039081  0.000000
# 3357  1.0  0.162233  0.537753  0.143140  0.651001  0.000000  0.000000
# 3358  1.0  0.152314  0.528798  0.133168  0.651873  0.060800  0.000000
# 3359  1.0  0.150085  0.534235  0.125199  0.651884  0.000000  0.000000
#
#       시간당적색광량  시간당청색광량    시간당총광량
# 0         0.0      0.0  0.000000
# 1         0.0      0.0  0.000000
# ...

# %%
sliced_list = slice_24(test_df2)

test_input = np.array(sliced_list)
test_input.shape
# Out:
# (140, 24, 10)

# %%
selected_model = load_model(models_list[0], custom_objects={'rmse':rmse})
print(models_list[0])

pred1 = selected_model.predict(test_input)
pred_df1 = pd.DataFrame(pred1, columns=['pred'])
# Out:
# C:/Users/ASIA-15/Desktop/Digital_Dev/sangchu/open/train_input/19-28/새 폴더/model_save/250-15.5004.hdf5
# 5/5 [==============================] - 0s 31ms/step

# %%
plt.figure(figsize=(16,9))
sns.lineplot(data = pred_df1, x=pred_df1.index, y='pred')
# Out:
# <AxesSubplot:ylabel='pred'>

# %%
pred_df1.to_csv('./test_pred_csv/pred_12_02_09_38.csv')
